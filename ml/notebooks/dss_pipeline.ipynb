# %% [markdown]
# # DSS ML Exploration
# Gunakan notebook ini untuk mengevaluasi kualitas data, merumuskan fitur, dan menguji ide model sebelum dipindahkan ke skrip produksi.

# %% [markdown]
# ## 1. Checklist Data
# - [ ] Export data pakan, kematian, telur dari database
# - [ ] Satukan rentang tanggal dan identitas kandang
# - [ ] Validasi missing value, outlier, dan satuan

# %%
# Placeholder import block
import pandas as pd
import plotly.express as px
from pathlib import Path

DATA_DIR = Path('..') / 'data'
RAW_DIR = DATA_DIR / 'raw'
PROCESSED_DIR = DATA_DIR / 'processed'

# %% [markdown]
# ## 2. Feature & Target Draft
# Tuliskan keputusan bisnis (label, horizon prediksi, agregasi) di sini sebelum difinalkan.

# %%
def summarize_batch(df, entity_cols, value_cols):
    """Contoh helper untuk agregasi per kandang/phase. Ganti dengan logika final."""
    raise NotImplementedError('Implementasikan summarization saat data siap')

def train_baseline(features, target):
    """Tempatkan baseline pertama (misal logistic regression)."""
    raise NotImplementedError('Ganti dengan eksperimen perdana')
